# %% [markdown]
# # Mini-Project I
# During this project, we will practice handling of complex lists and dictionaries in Python. Plus, we will learn how to work with API documentation. Don't be afraid to search for the information in the [**documentation**](https://api.tfl.gov.uk/swagger/ui/index.html?url=/swagger/docs/v1#!/AccidentStats/AccidentStats_Get).
#
# Let's go to the tasks, we have some parsing to do :)!!

# %%
# import packages we need (remember what packages we used yesterday during the API session)
# IMPORT HERE

# %%
import requests

# %%
import os

# %%
from IPython.display import JSON

# %% [markdown]
# ## Demo

# %%
# URL
url = "https://api.tfl.gov.uk/AirQuality"

# %%
# We send the request to the API
# NOTE: if you don't have your APP_KEY, run this without the url_append
res = requests.get(url)

# %%
# We can check if the request was successful
res.status_code
# Out:
# 200

# %%
json_res = res.json()

# %%
# We can export the information that was returned using method .json()
res.json()
# Out:
# {'$id': '1',
#  '$type': 'Tfl.Api.Presentation.Entities.LondonAirForecast, Tfl.Api.Presentation.Entities',
#  'updatePeriod': 'hourly',
#  'updateFrequency': '1',
#  'forecastURL': 'http://londonair.org.uk/forecast',
#  'disclaimerText': 'This forecast is intended to provide information on expected pollution levels in areas of significant public exposure. It may not apply in very specific locations close to unusually strong or short-lived local sources of pollution.',
#  'currentForecast': [{'$id': '2',
#    '$type': 'Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities',
#    'forecastType': 'Current',
#    'forecastID': '31818',
#    'forecastBand': 'Low',
#    'forecastSummary': 'Low air pollution forecast valid from Thursday 27 May to end of Thursday 27 May GMT',
#    'nO2Band': 'Low',
#    'o3Band': 'Low',
#    'pM10Band': 'Low',
#    'pM25Band': 'Low',
#    'sO2Band': 'Low',
#    'forecastText': 'Good sunshine early on Thursday, becoming cloudier.&lt;br/&gt;&lt;br/&gt;A very light breeze is forecast with an airflow in the main, north to south over the UK. &lt;br/&gt;&lt;br/&gt;Although we may see some build-up of local emissions, overall air pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM10 Particulate&lt;br/&gt;PM2.5 Particulate&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;'},
#   {'$id': '3',
#    '$type': 'Tfl.Api.Presentation.Entities.CurrentForecast, Tfl.Api.Presentation.Entities',
#    'forecastType': 'Future',
#    'forecastID': '31833',
#    'forecastBand': 'Low',
#    'forecastSummary': 'Low air pollution forecast valid from Friday 28 May to end of Friday 28 May GMT',
#    'nO2Band': 'Low',
#    'o3Band': 'Low',
#    'pM10Band': 'Low',
#    'pM25Band': 'Low',
#    'sO2Band': 'Low',
#    'forecastText': 'Friday will see the weather continuing to improve, with a dry, bright and sunny day.&lt;br/&gt;&lt;br/&gt;A light breeze may cause some build-up of local emissions, overall air pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM10 Particulate&lt;br/&gt;PM2.5 Particulate&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;'}]}

# %%
# using the ipython JSON 'ui'
JSON(json_res)

# %% [markdown]
# ## Task
# Parse the dictionary and print the AirQuality predictions for tomorrow

# %%
print(json_res["currentForecast"][1]["forecastText"])
# Out:
# Friday will see the weather continuing to improve, with a dry, bright and sunny day.&lt;br/&gt;&lt;br/&gt;A light breeze may cause some build-up of local emissions, overall air pollution is expected to remain &#39;Low&#39; for the following pollutants:&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;Nitrogen Dioxide&lt;br/&gt;Ozone&lt;br/&gt;PM10 Particulate&lt;br/&gt;PM2.5 Particulate&lt;br/&gt;Sulphur Dioxide&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;&lt;br/&gt;

# %% [markdown]
# ## Task
# What are the different modes of transport which are operated by Transfer for London? How many of modes do they have?
#
# Print the list with different modes of transport, plus their count. Example output:
# ```
# [bus, cable-car,.....]
# Number of different modes of transport is: xyz
# ```
#
# We need to search the documentation for correct request.

# %%
help(requests.get)
# Out:
# Help on function get in module requests.api:
#
# get(url, params=None, **kwargs)
#     Sends a GET request.
#
#     :param url: URL for the new :class:`Request` object.
#     :param params: (optional) Dictionary, list of tuples or bytes to send
#         in the query string for the :class:`Request`.
#     :param \*\*kwargs: Optional arguments that ``request`` takes.
#     :return: :class:`Response <Response>` object
#     :rtype: requests.Response

# %%
url = "https://api.tfl.gov.uk/Line/Route"
query = "serviceTypes"

# %%
res1 = requests.get(url + "?" + query)

# %%
json_res1 = res1.json()

# %%
modes_of_transport = []

for route in json_res1:
    if route["modeName"] not in modes_of_transport:
        modes_of_transport.append(route["modeName"])

print(modes_of_transport)
print(f"number of different modes of transport is {len(modes_of_transport)}")
# Out:
# ['bus', 'national-rail', 'tube', 'river-bus', 'dlr', 'cable-car', 'overground', 'tflrail', 'tram']
# number of different modes of transport is 9

# %%
json_res1
# Out:
# [{'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '1',
#   'name': '1',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'New Oxford Street - Canada Water Bus Station',
#     'direction': 'outbound',
#     'originationName': 'New Oxford Street',
#     'destinationName': 'Canada Water Bus Station',
#     'originator': '490000235Z',
#     'destination': '490004733D',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Canada Water Bus Station - Tottenham Court Road',
#     'direction': 'inbound',
#     'originationName': 'Canada Water Bus Station',
#     'destinationName': 'Tottenham Court Road',
#     'originator': '490004733C',
#     'destination': '490000235N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=1&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '100',
#   'name': '100',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': "King Edward Street / St Pauls Station - St George's Town Hall / Shadwell Stn",
#     'direction': 'outbound',
#     'originationName': 'King Edward Street / St Pauls Station',
#     'destinationName': "St George's Town Hall / Shadwell Stn",
#     'originator': '490008743N',
#     'destination': '490012020A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': "St George's Town Hall / Shadwell Stn - King Edward Street / St Pauls Station",
#     'direction': 'inbound',
#     'originationName': "St George's Town Hall / Shadwell Stn",
#     'destinationName': 'King Edward Street / St Pauls Station',
#     'originator': '490012020B',
#     'destination': '490008743N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=100&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '101',
#   'name': '101',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Gallions Reach Shopping Park - Woodbine Place',
#     'direction': 'inbound',
#     'originationName': 'Gallions Reach Shopping Park',
#     'destinationName': 'Woodbine Place',
#     'originator': '490016872S',
#     'destination': '490014816W',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Woodbine Place - Gallions Reach Shopping Park',
#     'direction': 'outbound',
#     'originationName': 'Woodbine Place',
#     'destinationName': 'Gallions Reach Shopping Park',
#     'originator': '490014816E',
#     'destination': '490016872AP',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=101&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '102',
#   'name': '102',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Brent Cross Shopping Centre - Edmonton Green Bus Station',
#     'direction': 'inbound',
#     'originationName': 'Brent Cross Shopping Centre',
#     'destinationName': 'Edmonton Green Bus Station',
#     'originator': '490004282D',
#     'destination': '490009983A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Edmonton Green Bus Station - Brent Cross Shopping Centre',
#     'direction': 'outbound',
#     'originationName': 'Edmonton Green Bus Station',
#     'destinationName': 'Brent Cross Shopping Centre',
#     'originator': '490009983G',
#     'destination': '490004282A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=102&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '103',
#   'name': '103',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Rainham Interchange - Chase Cross',
#     'direction': 'inbound',
#     'originationName': 'Rainham Interchange',
#     'destinationName': 'Chase Cross',
#     'originator': '490001235E',
#     'destination': '490005032E',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Chase Cross - Rainham Station',
#     'direction': 'outbound',
#     'originationName': 'Chase Cross',
#     'destinationName': 'Rainham Station',
#     'originator': '490005032E',
#     'destination': '490001235W',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=103&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '104',
#   'name': '104',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Manor Park / Gladding Road - Stratford Bus Station',
#     'direction': 'inbound',
#     'originationName': 'Manor Park / Gladding Road',
#     'destinationName': 'Stratford Bus Station',
#     'originator': '490009569N',
#     'destination': '490012904N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Stratford Bus Station - Manor Park / Gladding Road',
#     'direction': 'outbound',
#     'originationName': 'Stratford Bus Station',
#     'destinationName': 'Manor Park / Gladding Road',
#     'originator': '490012904D',
#     'destination': '490009569N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=104&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '105',
#   'name': '105',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Heathrow Central Bus Station - Greenford Station',
#     'direction': 'inbound',
#     'originationName': 'Heathrow Central Bus Station',
#     'destinationName': 'Greenford Station',
#     'originator': '4900801619',
#     'destination': '490000092W1',
#     'serviceType': 'Regular',
#     'validTo': '2021-05-28T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Rockware Avenue / Greenford Station - Heathrow Central Bus Station',
#     'direction': 'outbound',
#     'originationName': 'Rockware Avenue / Greenford Station',
#     'destinationName': 'Heathrow Central Bus Station',
#     'originator': '490000092W2',
#     'destination': '490008016S',
#     'serviceType': 'Regular',
#     'validTo': '2021-05-28T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=105&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '106',
#   'name': '106',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Finsbury Park Interchange - Cavell Street',
#     'direction': 'outbound',
#     'originationName': 'Finsbury Park Interchange',
#     'destinationName': 'Cavell Street',
#     'originator': '490000083H',
#     'destination': '490016619N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Cavell Street - Finsbury Park Interchange',
#     'direction': 'inbound',
#     'originationName': 'Cavell Street',
#     'destinationName': 'Finsbury Park Interchange',
#     'originator': '490016619N',
#     'destination': '490000083AP',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=106&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '107',
#   'name': '107',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Edgware Bus Station - New Barnet Station',
#     'direction': 'outbound',
#     'originationName': 'Edgware Bus Station',
#     'destinationName': 'New Barnet Station',
#     'originator': '490000070F',
#     'destination': '490001201S',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'New Barnet Station - Edgware Station',
#     'direction': 'inbound',
#     'originationName': 'New Barnet Station',
#     'destinationName': 'Edgware Station',
#     'originator': '490001201A',
#     'destination': '490000070G',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=107&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '108',
#   'name': '108',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Stratford International Station - Lewisham Station',
#     'direction': 'outbound',
#     'originationName': 'Stratford International Station',
#     'destinationName': 'Lewisham Station',
#     'originator': '490018554E1',
#     'destination': '490001177U',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Lewisham Centre - Stratford International Station',
#     'direction': 'inbound',
#     'originationName': 'Lewisham Centre',
#     'destinationName': 'Stratford International Station',
#     'originator': '490009105V',
#     'destination': '490018554W',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=108&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '109',
#   'name': '109',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.2Z',
#   'modified': '2021-05-25T15:01:14.2Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Brixton Road / Brixton Police Station - Park Street',
#     'direction': 'inbound',
#     'originationName': 'Brixton Road / Brixton Police Station',
#     'destinationName': 'Park Street',
#     'originator': '490007523G',
#     'destination': '490010839C3',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Katharine Street - Brixton Station',
#     'direction': 'outbound',
#     'originationName': 'Katharine Street',
#     'destinationName': 'Brixton Station',
#     'originator': '490013142C8',
#     'destination': '490000031R',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=109&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '11',
#   'name': '11',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Fulham Town Hall - Appold Street',
#     'direction': 'outbound',
#     'originationName': 'Fulham Town Hall',
#     'destinationName': 'Appold Street',
#     'originator': '490007057R',
#     'destination': '490016576AP',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Primrose Street - Fulham Town Hall',
#     'direction': 'inbound',
#     'originationName': 'Primrose Street',
#     'destinationName': 'Fulham Town Hall',
#     'originator': '490012391S',
#     'destination': '490007057T',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=11&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '110',
#   'name': '110',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'School Road - Hammersmith Bus Station',
#     'direction': 'outbound',
#     'originationName': 'School Road',
#     'destinationName': 'Hammersmith Bus Station',
#     'originator': '490015241B',
#     'destination': '490007705J',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Hammersmith Bus Station - Hounslow Bus Station',
#     'direction': 'inbound',
#     'originationName': 'Hammersmith Bus Station',
#     'destinationName': 'Hounslow Bus Station',
#     'originator': '490007705C',
#     'destination': '490008392Z1',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=110&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '111',
#   'name': '111',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Cromwell Road Bus Station - Heathrow Central Bus Station',
#     'direction': 'inbound',
#     'originationName': 'Cromwell Road Bus Station',
#     'destinationName': 'Heathrow Central Bus Station',
#     'originator': '490005800A7',
#     'destination': '490008016S',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Heathrow Central Bus Station - Cromwell Road Bus Station',
#     'direction': 'outbound',
#     'originationName': 'Heathrow Central Bus Station',
#     'destinationName': 'Cromwell Road Bus Station',
#     'originator': '4900801619',
#     'destination': '490005800A2',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=111&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '112',
#   'name': '112',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Haven Green / Ealing Broadway Station - North Finchley Bus Station',
#     'direction': 'outbound',
#     'originationName': 'Haven Green / Ealing Broadway Station',
#     'destinationName': 'North Finchley Bus Station',
#     'originator': '490007913D',
#     'destination': '490015443N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'North Finchley Bus Station - Ealing Broadway Station   / Haven Green',
#     'direction': 'inbound',
#     'originationName': 'North Finchley Bus Station',
#     'destinationName': 'Ealing Broadway Station   / Haven Green',
#     'originator': '490015443P',
#     'destination': '490000062A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=112&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '113',
#   'name': '113',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': "Edgware Bus Station - John Prince's Street / Oxford Circus",
#     'direction': 'outbound',
#     'originationName': 'Edgware Bus Station',
#     'destinationName': "John Prince's Street / Oxford Circus",
#     'originator': '490015287E',
#     'destination': '490000173JB',
#     'serviceType': 'Regular',
#     'validTo': '2021-05-28T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': "John Prince's Street / Oxford Circus - Edgware Station",
#     'direction': 'inbound',
#     'originationName': "John Prince's Street / Oxford Circus",
#     'destinationName': 'Edgware Station',
#     'originator': '490000173JC',
#     'destination': '490000070G',
#     'serviceType': 'Regular',
#     'validTo': '2021-05-28T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=113&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '114',
#   'name': '114',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Ruislip Station - Mill Hill Broadway Station',
#     'direction': 'inbound',
#     'originationName': 'Ruislip Station',
#     'destinationName': 'Mill Hill Broadway Station',
#     'originator': '490000197A',
#     'destination': '490001193B',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Mill Hill Broadway Station - Ruislip Station',
#     'direction': 'outbound',
#     'originationName': 'Mill Hill Broadway Station',
#     'destinationName': 'Ruislip Station',
#     'originator': '490001193B',
#     'destination': '490000197Z1',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=114&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '115',
#   'name': '115',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Aldgate Bus Station - East Ham / Central Park',
#     'direction': 'inbound',
#     'originationName': 'Aldgate Bus Station',
#     'destinationName': 'East Ham / Central Park',
#     'originator': '490003184L',
#     'destination': '490006358S2',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'East Ham / Central Park - Aldgate Station',
#     'direction': 'outbound',
#     'originationName': 'East Ham / Central Park',
#     'destinationName': 'Aldgate Station',
#     'originator': '490006358N',
#     'destination': '490000003R',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=115&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '116',
#   'name': '116',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'School Road - Ashford Hospital',
#     'direction': 'inbound',
#     'originationName': 'School Road',
#     'destinationName': 'Ashford Hospital',
#     'originator': '490015241B',
#     'destination': '40004402075A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Ashford Hospital - Hounslow Bus Station',
#     'direction': 'outbound',
#     'originationName': 'Ashford Hospital',
#     'destinationName': 'Hounslow Bus Station',
#     'originator': '40004402014A',
#     'destination': '490008392Z1',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=116&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '117',
#   'name': '117',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.2Z',
#   'modified': '2021-05-25T15:01:14.2Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Staines Bus Station - West London Mental Health Trust',
#     'direction': 'inbound',
#     'originationName': 'Staines Bus Station',
#     'destinationName': 'West London Mental Health Trust',
#     'originator': '40004402126B',
#     'destination': '490014493HE',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'West London Mental Health Trust - Staines Bus Station',
#     'direction': 'outbound',
#     'originationName': 'West London Mental Health Trust',
#     'destinationName': 'Staines Bus Station',
#     'originator': '490014493HE',
#     'destination': '40004402126J',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=117&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '118',
#   'name': '118',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Brixton Road / Brixton Police Station - Morden Station',
#     'direction': 'outbound',
#     'originationName': 'Brixton Road / Brixton Police Station',
#     'destinationName': 'Morden Station',
#     'originator': '490007523G',
#     'destination': '490000151L',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Morden Station - Brixton Station',
#     'direction': 'inbound',
#     'originationName': 'Morden Station',
#     'destinationName': 'Brixton Station',
#     'originator': '490000151C',
#     'destination': '490000031S',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=118&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '119',
#   'name': '119',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'The Colonnades / Croydon Airport - Bromley North Station',
#     'direction': 'inbound',
#     'originationName': 'The Colonnades / Croydon Airport',
#     'destinationName': 'Bromley North Station',
#     'originator': '490013304S2',
#     'destination': '490001036N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Bromley North Station - The Colonnades / Croydon Airport',
#     'direction': 'outbound',
#     'originationName': 'Bromley North Station',
#     'destinationName': 'The Colonnades / Croydon Airport',
#     'originator': '490001036D',
#     'destination': '490013304S1',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=119&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '12',
#   'name': '12',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Oxford Circus Stn  / Margaret Street - Dulwich Library',
#     'direction': 'outbound',
#     'originationName': 'Oxford Circus Stn  / Margaret Street',
#     'destinationName': 'Dulwich Library',
#     'originator': '490000173RF',
#     'destination': '490006232S',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Etherow Street - Margaret Street / Oxford Circus',
#     'direction': 'inbound',
#     'originationName': 'Etherow Street',
#     'destinationName': 'Margaret Street / Oxford Circus',
#     'originator': '490006652N',
#     'destination': '490000173N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=12&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '120',
#   'name': '120',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.2Z',
#   'modified': '2021-05-25T15:01:14.2Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Northolt Station - Hounslow Bus Station',
#     'direction': 'inbound',
#     'originationName': 'Northolt Station',
#     'destinationName': 'Hounslow Bus Station',
#     'originator': '490000162B',
#     'destination': '490008392Z1',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Hounslow Bus Station - Northolt Station',
#     'direction': 'outbound',
#     'originationName': 'Hounslow Bus Station',
#     'destinationName': 'Northolt Station',
#     'originator': '490008393W1',
#     'destination': '490000162A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=120&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '121',
#   'name': '121',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Enfield Island Village - Turnpike Lane Station',
#     'direction': 'outbound',
#     'originationName': 'Enfield Island Village',
#     'destinationName': 'Turnpike Lane Station',
#     'originator': '490006582N',
#     'destination': '490000241M',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Turnpike Lane Bus Station - Enfield Island Village',
#     'direction': 'inbound',
#     'originationName': 'Turnpike Lane Bus Station',
#     'destinationName': 'Enfield Island Village',
#     'originator': '490013852S',
#     'destination': '490006582N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=121&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '122',
#   'name': '122',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Plumstead Road / Plumstead Station - Crystal Palace Parade',
#     'direction': 'outbound',
#     'originationName': 'Plumstead Road / Plumstead Station',
#     'destinationName': 'Crystal Palace Parade',
#     'originator': '490001227E',
#     'destination': '490005869A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Crystal Palace Parade - Plumstead Bus Garage',
#     'direction': 'inbound',
#     'originationName': 'Crystal Palace Parade',
#     'destinationName': 'Plumstead Bus Garage',
#     'originator': '490005869B',
#     'destination': '490011069A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=122&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '123',
#   'name': '123',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Lordship Lane - Hainault Street',
#     'direction': 'outbound',
#     'originationName': 'Lordship Lane',
#     'destinationName': 'Hainault Street',
#     'originator': '490015567G2',
#     'destination': '490007657S',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Hainault Street - Wood Green Station',
#     'direction': 'inbound',
#     'originationName': 'Hainault Street',
#     'destinationName': 'Wood Green Station',
#     'originator': '490007657W',
#     'destination': '490014854HB',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=123&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '124',
#   'name': '124',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Holy Trinity Church - Stanstead Road / St Dunstans College',
#     'direction': 'inbound',
#     'originationName': 'Holy Trinity Church',
#     'destinationName': 'Stanstead Road / St Dunstans College',
#     'originator': '490008321S',
#     'destination': '490004863Z',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Stanstead Road / St Dunstans College - Southend Crescent / Southend Close',
#     'direction': 'outbound',
#     'originationName': 'Stanstead Road / St Dunstans College',
#     'destinationName': 'Southend Crescent / Southend Close',
#     'originator': '490004863Z',
#     'destination': '490012279S2',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=124&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '125',
#   'name': '125',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Station Road - Colindale Station',
#     'direction': 'outbound',
#     'originationName': 'Station Road',
#     'destinationName': 'Colindale Station',
#     'originator': '490012612A',
#     'destination': '490000054CR',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Colindale Station - Station Road',
#     'direction': 'inbound',
#     'originationName': 'Colindale Station',
#     'destinationName': 'Station Road',
#     'originator': '490000054CR',
#     'destination': '490012612A',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=125&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '126',
#   'name': '126',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Ringers Road - Eltham High Street / Foots Cray Road',
#     'direction': 'outbound',
#     'originationName': 'Ringers Road',
#     'destinationName': 'Eltham High Street / Foots Cray Road',
#     'originator': '490000282C',
#     'destination': '490006548E1',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Holy Trinity Church - Ringers Road',
#     'direction': 'inbound',
#     'originationName': 'Holy Trinity Church',
#     'destinationName': 'Ringers Road',
#     'originator': '490008321S',
#     'destination': '490000282C',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=126&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '127',
#   'name': '127',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Purley Station - Tooting Broadway Station',
#     'direction': 'outbound',
#     'originationName': 'Purley Station',
#     'destinationName': 'Tooting Broadway Station',
#     'originator': '490001229H',
#     'destination': '490000234W1',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Mitcham Road / Tooting Broadway Stn - Purley Station',
#     'direction': 'inbound',
#     'originationName': 'Mitcham Road / Tooting Broadway Stn',
#     'destinationName': 'Purley Station',
#     'originator': '490000234C',
#     'destination': '490001229J',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=127&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': '128',
#   'name': '128',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Claybury Broadway - Romford Station',
#     'direction': 'inbound',
#     'originationName': 'Claybury Broadway',
#     'destinationName': 'Romford Station',
#     'originator': '490005368N',
#     'destination': '490001243W',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Romford Station - Claybury Broadway',
#     'direction': 'outbound',
#     'originationName': 'Romford Station',
#     'destinationName': 'Claybury Broadway',
#     'originator': '490001243ZA',
#     'destination': '490005368N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Claybury Broadway - Romford Station',
#     'direction': 'inbound',
#     'originationName': 'Claybury Broadway',
#     'destinationName': 'Romford Station',
#     'originator': '490005368N',
#     'destination': '490001243W',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Romford Station - Claybury Broadway',
#     'direction': 'outbound',
#     'originationName': 'Romford Station',
#     'destinationName': 'Claybury Broadway',
#     'originator': '490001243ZA',
#     'destination': '490005368N',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
# ...
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Northampton Rail Station - London Euston Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Northampton Rail Station',
#     'destinationName': 'London Euston Rail Station',
#     'originator': '910GNMPTN',
#     'destination': '910GEUSTON',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Rugby Rail Station - London Euston Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Rugby Rail Station',
#     'destinationName': 'London Euston Rail Station',
#     'originator': '910GRUGBY',
#     'destination': '910GEUSTON',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Redditch Rail Station - Lichfield Trent Valley HL Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Redditch Rail Station',
#     'destinationName': 'Lichfield Trent Valley HL Rail Station',
#     'originator': '910GRDIT',
#     'destination': '910GLCHTTVH',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Lichfield Trent Valley HL Rail Station - Redditch Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Lichfield Trent Valley HL Rail Station',
#     'destinationName': 'Redditch Rail Station',
#     'originator': '910GLCHTTVH',
#     'destination': '910GRDIT',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Bromsgrove Rail Station - Lichfield Trent Valley HL Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Bromsgrove Rail Station',
#     'destinationName': 'Lichfield Trent Valley HL Rail Station',
#     'originator': '910GBRMSGRV',
#     'destination': '910GLCHTTVH',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Lichfield Trent Valley HL Rail Station - Bromsgrove Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Lichfield Trent Valley HL Rail Station',
#     'destinationName': 'Bromsgrove Rail Station',
#     'originator': '910GLCHTTVH',
#     'destination': '910GBRMSGRV',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Wolverhampton Rail Station - Birmingham New Street Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Wolverhampton Rail Station',
#     'destinationName': 'Birmingham New Street Rail Station',
#     'originator': '910GWVRMPTN',
#     'destination': '910GBHAMNWS',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Birmingham New Street Rail Station - Wolverhampton Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Birmingham New Street Rail Station',
#     'destinationName': 'Wolverhampton Rail Station',
#     'originator': '910GBHAMNWS',
#     'destination': '910GWVRMPTN',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Rugeley Trent Valley Rail Station - Northampton Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Rugeley Trent Valley Rail Station',
#     'destinationName': 'Northampton Rail Station',
#     'originator': '910GRUGL',
#     'destination': '910GNMPTN',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Northampton Rail Station - Rugeley Trent Valley Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Northampton Rail Station',
#     'destinationName': 'Rugeley Trent Valley Rail Station',
#     'originator': '910GNMPTN',
#     'destination': '910GRUGL',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Rugeley Trent Valley Rail Station - Birmingham New Street Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Rugeley Trent Valley Rail Station',
#     'destinationName': 'Birmingham New Street Rail Station',
#     'originator': '910GRUGL',
#     'destination': '910GBHAMNWS',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Birmingham New Street Rail Station - Hereford Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Birmingham New Street Rail Station',
#     'destinationName': 'Hereford Rail Station',
#     'originator': '910GBHAMNWS',
#     'destination': '910GHEREFRD',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Hereford Rail Station - Birmingham New Street Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Hereford Rail Station',
#     'destinationName': 'Birmingham New Street Rail Station',
#     'originator': '910GHEREFRD',
#     'destination': '910GBHAMNWS',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Stratford-upon-Avon Rail Station - Hereford Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Stratford-upon-Avon Rail Station',
#     'destinationName': 'Hereford Rail Station',
#     'originator': '910GSOAV',
#     'destination': '910GHEREFRD',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Hereford Rail Station - Stratford-upon-Avon Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Hereford Rail Station',
#     'destinationName': 'Stratford-upon-Avon Rail Station',
#     'originator': '910GHEREFRD',
#     'destination': '910GSOAV',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Leamington Spa Rail Station - Droitwich Spa Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Leamington Spa Rail Station',
#     'destinationName': 'Droitwich Spa Rail Station',
#     'originator': '910GLMNGTNS',
#     'destination': '910GDRTWCHS',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Stourbridge Town Rail Station - Stourbridge Junction Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Stourbridge Town Rail Station',
#     'destinationName': 'Stourbridge Junction Rail Station',
#     'originator': '910GSTRBDGT',
#     'destination': '910GSTRBDGJ',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Stourbridge Junction Rail Station - Stourbridge Town Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Stourbridge Junction Rail Station',
#     'destinationName': 'Stourbridge Town Rail Station',
#     'originator': '910GSTRBDGJ',
#     'destination': '910GSTRBDGT',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Shrewsbury Rail Station - Birmingham New Street Rail Station',
#     'direction': 'inbound',
#     'originationName': 'Shrewsbury Rail Station',
#     'destinationName': 'Birmingham New Street Rail Station',
#     'originator': '910GSHRWBY',
#     'destination': '910GBHAMNWS',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Rugeley Trent Valley Rail Station - Shrewsbury Rail Station',
#     'direction': 'outbound',
#     'originationName': 'Rugeley Trent Valley Rail Station',
#     'destinationName': 'Shrewsbury Rail Station',
#     'originator': '910GRUGL',
#     'destination': '910GSHRWBY',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=West Midlands Trains&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': 'woolwich-ferry',
#   'name': 'Woolwich Ferry',
#   'modeName': 'river-bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Woolwich Ferry North Pier - Woolwich Ferry South Pier',
#     'direction': 'inbound',
#     'originationName': 'Woolwich Ferry North Pier',
#     'destinationName': 'Woolwich Ferry South Pier',
#     'originator': '930GWWC',
#     'destination': '930GWWS',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Woolwich Ferry South Pier - Woolwich Ferry North Pier',
#     'direction': 'outbound',
#     'originationName': 'Woolwich Ferry South Pier',
#     'destinationName': 'Woolwich Ferry North Pier',
#     'originator': '930GWWS',
#     'destination': '930GWWC',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=Woolwich Ferry&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': 'x140',
#   'name': 'X140',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.17Z',
#   'modified': '2021-05-25T15:01:14.17Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Harrow Bus Station - Heathrow Central Bus Station',
#     'direction': 'inbound',
#     'originationName': 'Harrow Bus Station',
#     'destinationName': 'Heathrow Central Bus Station',
#     'originator': '490007845B',
#     'destination': '490008016S',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Heathrow Central Bus Station - Harrow Bus Station',
#     'direction': 'outbound',
#     'originationName': 'Heathrow Central Bus Station',
#     'destinationName': 'Harrow Bus Station',
#     'originator': '4900801619',
#     'destination': '490007845E',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=X140&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': 'x26',
#   'name': 'X26',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Heathrow Central Bus Station - Delta Point',
#     'direction': 'inbound',
#     'originationName': 'Heathrow Central Bus Station',
#     'destinationName': 'Delta Point',
#     'originator': '4900801619',
#     'destination': '490017825WN',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'West Croydon Bus Station - Heathrow Central Bus Station',
#     'direction': 'outbound',
#     'originationName': 'West Croydon Bus Station',
#     'destinationName': 'Heathrow Central Bus Station',
#     'originator': '490014420X',
#     'destination': '490008016S',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=X26&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}},
#  {'$type': 'Tfl.Api.Presentation.Entities.Line, Tfl.Api.Presentation.Entities',
#   'id': 'x68',
#   'name': 'X68',
#   'modeName': 'bus',
#   'disruptions': [],
#   'created': '2021-05-25T15:01:14.187Z',
#   'modified': '2021-05-25T15:01:14.187Z',
#   'lineStatuses': [],
#   'routeSections': [{'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'Russell Square - West Croydon Bus Station',
#     'direction': 'inbound',
#     'originationName': 'Russell Square',
#     'destinationName': 'West Croydon Bus Station',
#     'originator': '490000200E',
#     'destination': '490014420Z',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'},
#    {'$type': 'Tfl.Api.Presentation.Entities.MatchedRoute, Tfl.Api.Presentation.Entities',
#     'name': 'West Croydon Bus Station - Russell Square',
#     'direction': 'outbound',
#     'originationName': 'West Croydon Bus Station',
#     'destinationName': 'Russell Square',
#     'originator': '490014420V',
#     'destination': '490000200D',
#     'serviceType': 'Regular',
#     'validTo': '2021-11-23T00:00:00Z',
#     'validFrom': '2021-05-22T00:00:00Z'}],
#   'serviceTypes': [{'$type': 'Tfl.Api.Presentation.Entities.LineServiceTypeInfo, Tfl.Api.Presentation.Entities',
#     'name': 'Regular',
#     'uri': '/Line/Route?ids=X68&serviceTypes=Regular'}],
#   'crowding': {'$type': 'Tfl.Api.Presentation.Entities.Crowding, Tfl.Api.Presentation.Entities'}}]

# %% [markdown]
# ## Task
# How many BikePoints in London are operated by Transfor for London? How many docks are in **all** BikePoints? There is the information for empty and full docks for each BikePoint.

# %% [markdown]
# ## Task
# How many tube and bus lines are in London? Print names of all tube lines.

# %% [markdown]
# ## Task
# How many station has `victoria` line?

# %% [markdown]
# ## Task
# Plan the journey from Heathrow Airport to Tower Bridge using Bus and Tube? Which way is faster? Example output:
# ```
# Planned duration:
# Bus: x minutes
# Tube: y minutes
# ```
#
# We need to search the documentation for correct requests and parameters we need.
